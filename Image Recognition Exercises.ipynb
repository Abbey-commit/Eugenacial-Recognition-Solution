# %% [markdown]
# ### The following code display the operation of an image recognition using an inbuilt dataset from scikit learn in skimage to read, and also to transform the data. Then, used matplotlib to display the matplotlib

# %%
from skimage.io import imread
from skimage.transform import resize
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
example_file = ("http://upload.wikimedia.org/" + 
                "wikipedia/commons/7/7d/Dog_face.png")
image = imread(example_file, as_grey=True)
plt.imshow(image, cmap=cm.gray)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# C:\anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# C:\anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ...
